# %%
import numpy as np
import scipy
import scipy.sparse
from sklearn.cluster import MiniBatchKMeans
import time
import datetime
import pandas as pd
from sklearn.metrics.pairwise import euclidean_distances

# %%
#params
skip_preprocessing = True
input_data = '/Users/lo/Programming/emoji_scripts/m2v_specific_true_sep.csv'
file_name = 'm2v_specific_true'

data = pd.read_csv(input_data, sep=';')
number_of_cols = len(data.columns)
number_of_rows = len(data)
print('cols', number_of_cols, 'rows', number_of_rows)

number_of_clusters = (int)(number_of_rows/1000)
batch_size = (int)(0.3*number_of_rows)
maximum_kmeans_iterations = 100
number_of_initialisations = 10

output_file = str(file_name + '_medoids_clus_' + str(number_of_clusters) + '_b_size_' + str(batch_size) + '_iter_' + str(maximum_kmeans_iterations) + '_init_' + str(number_of_initialisations) + '.csv')
print(output_file)
# Out:
# cols 302 rows 2003064
# m2v_specific_true_medoids_clus_2003_b_size_600919_iter_100_init_10.csv

# %%
#remove one value columns
if not skip_preprocessing:
    start_time = time.time()
    print('start time', time.ctime())
    columns_to_remove = []

    for col in data.columns:
        column_data = data.loc[:,col]

        if len(column_data.unique()) == 1:
            print('only one value in column', col)
            columns_to_remove.append(col)

    print('before dropping empty columns', len(data.columns))
    data.drop(columns=columns_to_remove)
    print('after dropping empty columns', len(data.columns))
    
    elapsed_time = time.time() - start_time
    print('end time', str(datetime.timedelta(seconds=elapsed_time)))

# %%
# def find_nan_in_csr(X, verbose=False):
#     num_of_nans = 0
#     num_of_infs = 0
    
#     X = scipy.sparse.coo_matrix(X)
#     for i, j, v in zip(X.row, X.col, X.data):
#         if np.isnan(v):
#             num_of_nans += 1
#             if verbose:
#                 print(i, j, v)
#         elif np.isinf(v):
#             num_of_infs += 1
#             if verbose:
#                 print(i, j, v)
            
#     print('num of nans', num_of_nans)
#     print('num of infs', num_of_infs)
#     return None

# %%
# find_nan_in_csr(data_sparse, verbose=True)
# np.nan_to_num(data_sparse.data, copy=False)
# data_sparse.eliminate_zeros()
# find_nan_in_csr(data_sparse)

# %%
start_time = time.time()
print('start time', time.ctime())
print('number_of_clusters', number_of_clusters)
kmeans = MiniBatchKMeans(n_clusters=number_of_clusters, init='k-means++', max_iter=maximum_kmeans_iterations, batch_size=batch_size, verbose=True, compute_labels=True, n_init=number_of_initialisations)
kmeans = kmeans.fit(data)
elapsed_time = time.time() - start_time
print('inertia value', kmeans.inertia_)
print('end time', str(datetime.timedelta(seconds=elapsed_time)))
# Out:
# start time Fri Mar  8 01:43:28 2019
# number_of_clusters 2003
# Init 1/10 with method: k-means++
# Inertia for init 1/10: 162184296452.050385
# Init 2/10 with method: k-means++
# Inertia for init 2/10: 162090686218.869629
# Init 3/10 with method: k-means++
# Inertia for init 3/10: 161544993206.261810
# Init 4/10 with method: k-means++
# Inertia for init 4/10: 162277957095.464111
# Init 5/10 with method: k-means++
# Inertia for init 5/10: 162247280894.825684
# Init 6/10 with method: k-means++
# Inertia for init 6/10: 162166584337.349335
# Init 7/10 with method: k-means++
# Inertia for init 7/10: 161323039375.063141
# Init 8/10 with method: k-means++
# Inertia for init 8/10: 162252580534.059967
# Init 9/10 with method: k-means++
# Inertia for init 9/10: 161734563642.818512
# Init 10/10 with method: k-means++
# Inertia for init 10/10: 161729225779.395081
# Minibatch iteration 1/400: mean batch inertia: 89566.666839, ewa inertia: 89566.666839
# Minibatch iteration 2/400: mean batch inertia: 89166.587468, ewa inertia: 89326.619416
# Minibatch iteration 3/400: mean batch inertia: 88709.821191, ewa inertia: 88956.540789
# Minibatch iteration 4/400: mean batch inertia: 88524.151209, ewa inertia: 88697.107257
# Minibatch iteration 5/400: mean batch inertia: 88365.316048, ewa inertia: 88498.032697
# Minibatch iteration 6/400: mean batch inertia: 88065.896419, ewa inertia: 88238.751146
# Minibatch iteration 7/400: mean batch inertia: 88108.934425, ewa inertia: 88160.861178
# Minibatch iteration 8/400: mean batch inertia: 87981.279976, ewa inertia: 88053.112547
# Minibatch iteration 9/400: mean batch inertia: 88008.323819, ewa inertia: 88026.239333
# Minibatch iteration 10/400: mean batch inertia: 87813.489925, ewa inertia: 87898.589794
# Minibatch iteration 11/400: mean batch inertia: 87592.294333, ewa inertia: 87714.812671
# Minibatch iteration 12/400: mean batch inertia: 87760.435206, ewa inertia: 87742.186169
# Minibatch iteration 13/400: mean batch inertia: 87681.022065, ewa inertia: 87705.487737
# Minibatch iteration 14/400: mean batch inertia: 87329.379978, ewa inertia: 87479.823269
# Minibatch iteration 15/400: mean batch inertia: 87300.196651, ewa inertia: 87372.047388
# Minibatch iteration 16/400: mean batch inertia: 87456.713259, ewa inertia: 87422.846868
# Minibatch iteration 17/400: mean batch inertia: 87375.177845, ewa inertia: 87394.245478
# Minibatch iteration 18/400: mean batch inertia: 87327.913063, ewa inertia: 87354.446062
# Minibatch iteration 19/400: mean batch inertia: 87323.430826, ewa inertia: 87335.836936
# Minibatch iteration 20/400: mean batch inertia: 87186.552172, ewa inertia: 87246.266152
# Minibatch iteration 21/400: mean batch inertia: 87323.956734, ewa inertia: 87292.880463
# Minibatch iteration 22/400: mean batch inertia: 87185.761168, ewa inertia: 87228.608939
# Minibatch iteration 23/400: mean batch inertia: 87142.606284, ewa inertia: 87177.007389
# Minibatch iteration 24/400: mean batch inertia: 87120.590049, ewa inertia: 87143.157013
# Minibatch iteration 25/400: mean batch inertia: 87071.124216, ewa inertia: 87099.937371
# Minibatch iteration 26/400: mean batch inertia: 87235.199841, ewa inertia: 87181.094785
# Minibatch iteration 27/400: mean batch inertia: 87204.106584, ewa inertia: 87194.901853
# Minibatch iteration 28/400: mean batch inertia: 87099.012805, ewa inertia: 87137.368472
# Minibatch iteration 29/400: mean batch inertia: 87284.743778, ewa inertia: 87225.793582
# Minibatch iteration 30/400: mean batch inertia: 87025.385731, ewa inertia: 87105.548971
# Minibatch iteration 31/400: mean batch inertia: 87136.743429, ewa inertia: 87124.265630
# Minibatch iteration 32/400: mean batch inertia: 87141.447115, ewa inertia: 87134.574513
# Minibatch iteration 33/400: mean batch inertia: 86979.394972, ewa inertia: 87041.466866
# Minibatch iteration 34/400: mean batch inertia: 87124.683846, ewa inertia: 87091.397012
# Minibatch iteration 35/400: mean batch inertia: 87009.063744, ewa inertia: 87041.997092
# Minibatch iteration 36/400: mean batch inertia: 87044.908636, ewa inertia: 87043.744017
# Minibatch iteration 37/400: mean batch inertia: 86808.748655, ewa inertia: 86902.746917
# Minibatch iteration 38/400: mean batch inertia: 86999.676506, ewa inertia: 86960.904622
# Minibatch iteration 39/400: mean batch inertia: 87231.789057, ewa inertia: 87123.435148
# Minibatch iteration 40/400: mean batch inertia: 86932.081285, ewa inertia: 87008.622926
# Minibatch iteration 41/400: mean batch inertia: 86683.813990, ewa inertia: 86813.737727
# Minibatch iteration 42/400: mean batch inertia: 87052.558216, ewa inertia: 86957.029901
# Minibatch iteration 43/400: mean batch inertia: 86908.822445, ewa inertia: 86928.105452
# Minibatch iteration 44/400: mean batch inertia: 86914.597820, ewa inertia: 86920.000880
# Minibatch iteration 45/400: mean batch inertia: 86962.355308, ewa inertia: 86945.413516
# Minibatch iteration 46/400: mean batch inertia: 86866.465409, ewa inertia: 86898.044691
# Minibatch iteration 47/400: mean batch inertia: 86901.746879, ewa inertia: 86900.266002
# Minibatch iteration 48/400: mean batch inertia: 86873.161761, ewa inertia: 86884.003471
# Minibatch iteration 49/400: mean batch inertia: 86667.423737, ewa inertia: 86754.055738
# Minibatch iteration 50/400: mean batch inertia: 86767.721728, ewa inertia: 86762.255326
# Minibatch iteration 51/400: mean batch inertia: 86783.537971, ewa inertia: 86775.024902
# Minibatch iteration 52/400: mean batch inertia: 86783.798447, ewa inertia: 86780.289025
# Minibatch iteration 53/400: mean batch inertia: 86645.806772, ewa inertia: 86699.599740
# Minibatch iteration 54/400: mean batch inertia: 86563.054265, ewa inertia: 86617.672523
# Minibatch iteration 55/400: mean batch inertia: 86646.136902, ewa inertia: 86634.751136
# Minibatch iteration 56/400: mean batch inertia: 86714.375287, ewa inertia: 86682.525587
# Minibatch iteration 57/400: mean batch inertia: 86643.756188, ewa inertia: 86659.263967
# Minibatch iteration 58/400: mean batch inertia: 86633.251813, ewa inertia: 86643.656687
# Minibatch iteration 59/400: mean batch inertia: 86598.227462, ewa inertia: 86616.399175
# Minibatch iteration 60/400: mean batch inertia: 86890.231713, ewa inertia: 86780.698561
# Minibatch iteration 61/400: mean batch inertia: 86729.980352, ewa inertia: 86750.267661
# Minibatch iteration 62/400: mean batch inertia: 86518.064949, ewa inertia: 86610.946150
# Minibatch iteration 63/400: mean batch inertia: 86598.083504, ewa inertia: 86603.228569
# Minibatch iteration 64/400: mean batch inertia: 86645.994511, ewa inertia: 86628.888113
# Minibatch iteration 65/400: mean batch inertia: 86904.155343, ewa inertia: 86794.048313
# Minibatch iteration 66/400: mean batch inertia: 86607.308090, ewa inertia: 86682.004273
# Minibatch iteration 67/400: mean batch inertia: 86691.287579, ewa inertia: 86687.574252
# Minibatch iteration 68/400: mean batch inertia: 86777.726503, ewa inertia: 86741.665558
# Minibatch iteration 69/400: mean batch inertia: 86616.120772, ewa inertia: 86666.338749
# Minibatch iteration 70/400: mean batch inertia: 86544.945838, ewa inertia: 86593.503063
# Minibatch iteration 71/400: mean batch inertia: 86566.500038, ewa inertia: 86577.301261
# Minibatch iteration 72/400: mean batch inertia: 86648.239964, ewa inertia: 86619.864448
# Minibatch iteration 73/400: mean batch inertia: 86650.574584, ewa inertia: 86638.290514
# Minibatch iteration 74/400: mean batch inertia: 86616.785945, ewa inertia: 86625.387783
# Minibatch iteration 75/400: mean batch inertia: 86641.858685, ewa inertia: 86635.270316
# Minibatch iteration 76/400: mean batch inertia: 86742.426129, ewa inertia: 86699.563750
# Minibatch iteration 77/400: mean batch inertia: 86432.656720, ewa inertia: 86539.419665
# Minibatch iteration 78/400: mean batch inertia: 86791.013993, ewa inertia: 86690.376137
# Minibatch iteration 79/400: mean batch inertia: 86588.290126, ewa inertia: 86629.124581
# Minibatch iteration 80/400: mean batch inertia: 86595.463114, ewa inertia: 86608.927717
# Minibatch iteration 81/400: mean batch inertia: 86444.957669, ewa inertia: 86510.545770
# Minibatch iteration 82/400: mean batch inertia: 86683.550523, ewa inertia: 86614.348536
# Minibatch iteration 83/400: mean batch inertia: 86626.748814, ewa inertia: 86621.788697
# Minibatch iteration 84/400: mean batch inertia: 86623.933365, ewa inertia: 86623.075496
# Minibatch iteration 85/400: mean batch inertia: 86693.257556, ewa inertia: 86665.184697
# Minibatch iteration 86/400: mean batch inertia: 86528.217859, ewa inertia: 86583.004663
# Minibatch iteration 87/400: mean batch inertia: 86474.623601, ewa inertia: 86517.976080
# Minibatch iteration 88/400: mean batch inertia: 86549.915500, ewa inertia: 86537.139716
# Minibatch iteration 89/400: mean batch inertia: 86504.211328, ewa inertia: 86517.382699
# Minibatch iteration 90/400: mean batch inertia: 86690.220747, ewa inertia: 86621.085442
# Minibatch iteration 91/400: mean batch inertia: 86643.623027, ewa inertia: 86634.607982
# Converged (lack of improvement in inertia) at iteration 91/400
# Computing label assignment and total inertia
# inertia value 173371633082.41864
# end time 18:59:24.780798

# %%
# (kmeans.cluster_centers_.tolist())
# print(kmeans.labels_)

cluster_assignment_row_indices = {}

# print('max cluster label', kmeans.labels_.max())

for i in range(0, kmeans.labels_.max()+1):
    cluster_assignment_row_indices[i] = []
    

for idx, val in enumerate(kmeans.labels_):
    cluster_assignment_row_indices[val].append(idx)
    
# print(cluster_assignment_row_indices)

medoid_indices = []
empty_clusters = 0
print('number of centres', len(kmeans.cluster_centers_))
for key in cluster_assignment_row_indices:
#     print(key)
    assigned_points = cluster_assignment_row_indices[key]
    
    if len(assigned_points) != 0:
#         print('points', assigned_points)
        points_data = data.iloc[assigned_points, :]
#         print('points data len', len(points_data))
    #     print(points_data)
        centre = kmeans.cluster_centers_[key]
    #     print(type(centre))
        centre_sparse = scipy.sparse.csr_matrix(centre)
    #     print('centre:\n', centre_sparse)
        distances = euclidean_distances(X=[centre], Y=points_data)
    #     print(distances)
        centroid_closes_point_index = np.argmin(distances)
    #     print('index of closest point', centroid_closes_point_index)
        medoid_indices.append(assigned_points[centroid_closes_point_index])
    else:
        empty_clusters += 1
    
print('number of medoids', len(medoid_indices))
print('number of empty clusters', empty_clusters)
medoid_data = data.iloc[medoid_indices, :]
# Out:
# number of centres 2003
# number of medoids 2003
# number of empty clusters 0

# %%
display(medoid_data.head())
print('number of columns', len(medoid_data.columns))

cols_to_remove = []
for col in medoid_data.columns:
#     print(col)
#     print(medoid_data_dense[col])
    if len(medoid_data.loc[:, col].unique()) == 1:
        cols_to_remove.append(col)
        
print('number_of_columns_to_remove', len(cols_to_remove))
# print(cols_to_remove)
medoid_data.drop(columns=cols_to_remove, inplace=True)
display(medoid_data.head())
print('number of rows', len(medoid_data), 'columns', len(medoid_data.columns))
# Out:
#          Unnamed: 0         0         1         2         3         4  \
# 1476549     1476549 -0.037389 -0.161603  0.002510 -0.084047 -0.046386
# 556515       556515  0.048810 -0.059084  0.028075 -0.108739  0.009216
# 158581       158581  0.040506 -0.116480  0.050503 -0.061919 -0.067655
# 974756       974756  0.072404 -0.141246  0.011830 -0.010276 -0.029610
# 1843195     1843195  0.056374 -0.100911  0.039099 -0.030588 -0.004959
#
#                 5         6         7         8  ...       291       292  \
# 1476549  0.051671 -0.177254 -0.053380 -0.021205  ... -0.045205 -0.039144
# 556515   0.037656  0.021714  0.050400 -0.075699  ... -0.043923 -0.020800
# 158581   0.019092 -0.111906  0.050519  0.028107  ... -0.017497 -0.039151
# 974756  -0.043870 -0.102447  0.013691  0.003988  ... -0.036338 -0.163747
# 1843195  0.002027 -0.181162  0.054123 -0.044202  ... -0.067880 -0.063911
#
#               293       294       295       296       297       298       299  \
# 1476549 -0.060718  0.072623  0.013894  0.071807 -0.015601 -0.094214  0.080718
# 556515  -0.167360  0.076087 -0.037813  0.064219 -0.030496 -0.007044  0.059909
# 158581  -0.045370  0.003349 -0.063243 -0.052938 -0.037063 -0.058466  0.036524
# 974756  -0.032808 -0.005834 -0.070330 -0.006092  0.035623 -0.076001  0.076440
# 1843195 -0.053409  0.067435 -0.049773 -0.033076  0.013400 -0.034776 -0.021918
#
#          300
# 1476549  1.0
# 556515   0.0
# 158581   0.0
# 974756   0.0
# 1843195  0.0
#
# [5 rows x 302 columns]
# number of columns 302
# number_of_columns_to_remove 0
# /Users/lo/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3930: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#          Unnamed: 0         0         1         2         3         4  \
# 1476549     1476549 -0.037389 -0.161603  0.002510 -0.084047 -0.046386
# 556515       556515  0.048810 -0.059084  0.028075 -0.108739  0.009216
# 158581       158581  0.040506 -0.116480  0.050503 -0.061919 -0.067655
# 974756       974756  0.072404 -0.141246  0.011830 -0.010276 -0.029610
# 1843195     1843195  0.056374 -0.100911  0.039099 -0.030588 -0.004959
#
#                 5         6         7         8  ...       291       292  \
# 1476549  0.051671 -0.177254 -0.053380 -0.021205  ... -0.045205 -0.039144
# 556515   0.037656  0.021714  0.050400 -0.075699  ... -0.043923 -0.020800
# 158581   0.019092 -0.111906  0.050519  0.028107  ... -0.017497 -0.039151
# 974756  -0.043870 -0.102447  0.013691  0.003988  ... -0.036338 -0.163747
# 1843195  0.002027 -0.181162  0.054123 -0.044202  ... -0.067880 -0.063911
#
#               293       294       295       296       297       298       299  \
# 1476549 -0.060718  0.072623  0.013894  0.071807 -0.015601 -0.094214  0.080718
# 556515  -0.167360  0.076087 -0.037813  0.064219 -0.030496 -0.007044  0.059909
# 158581  -0.045370  0.003349 -0.063243 -0.052938 -0.037063 -0.058466  0.036524
# 974756  -0.032808 -0.005834 -0.070330 -0.006092  0.035623 -0.076001  0.076440
# 1843195 -0.053409  0.067435 -0.049773 -0.033076  0.013400 -0.034776 -0.021918
#
#          300
# 1476549  1.0
# 556515   0.0
# 158581   0.0
# 974756   0.0
# 1843195  0.0
#
# [5 rows x 302 columns]
# number of rows 2003 columns 302

# %%
medoid_data.to_csv(output_file)
